# %% [markdown]
# <a href="https://colab.research.google.com/github/FishyDanny/Road-Safety-Risk-Prediction/blob/main/04_train_deep_learning_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
# !pip install keras-tuner -q
import numpy as np
import pandas as pd
import joblib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_auc_score, RocCurveDisplay
import keras_tuner as kt
from sklearn.metrics import f1_score, roc_auc_score, RocCurveDisplay
from google.colab import drive
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.8 MB/s eta 0:00:00

# %%
drive.mount('/content/drive')

# Load preprocessed data
X_train = joblib.load('/content/drive/MyDrive/ACTL3143_project/processed/X_train.pkl')
X_val = joblib.load('/content/drive/MyDrive/ACTL3143_project/processed/X_val.pkl')
y_train = joblib.load('/content/drive/MyDrive/ACTL3143_project/processed/y_train.pkl')
y_val = joblib.load('/content/drive/MyDrive/ACTL3143_project/processed/y_val.pkl')
X_test = joblib.load('/content/drive/MyDrive/ACTL3143_project/processed/X_test.pkl')
y_test = joblib.load('/content/drive/MyDrive/ACTL3143_project/processed/y_test.pkl')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
keras.utils.set_random_seed(42)

# %%
# For the first model (feedforward)
first_tuner = kt.BayesianOptimization(
    keras.models.load_model('/content/drive/MyDrive/ACTL3143_project/best_first_model.keras'),
    objective='val_auc',
    max_trials=0,
    directory='/content/drive/MyDrive/ACTL3143_project/tuning',
    project_name='first_model'
)
first_tuner.reload()

# For the second model (residual)
second_tuner = kt.BayesianOptimization(
    keras.models.load_model('/content/drive/MyDrive/ACTL3143_project/best_second_model.keras'),
    objective='val_auc',
    max_trials=0,
    directory='/content/drive/MyDrive/ACTL3143_project/tuning',
    project_name='second_model'
)
second_tuner.reload()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 34 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Reloading Tuner from /content/drive/MyDrive/ACTL3143_project/tuning/first_model/tuner0.json
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 62 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Reloading Tuner from /content/drive/MyDrive/ACTL3143_project/tuning/second_model/tuner0.json

# %%
# Get best hyperparameters
best_first_hps = first_tuner.get_best_hyperparameters()[0]
best_second_hps = second_tuner.get_best_hyperparameters()[0]

print("First model best hyperparameters:")
print(best_first_hps.values)

print("\nSecond model best hyperparameters:")
print(best_second_hps.values)
# Out:
# First model best hyperparameters:
# {'num_layers': 3, 'units_0': 192, 'dropout_0': 0.30000000000000004, 'lr': 0.0006562893605899151, 'units_1': 192, 'dropout_1': 0.1, 'units_2': 128, 'dropout_2': 0.5, 'units_3': 192, 'dropout_3': 0.30000000000000004}
#
# Second model best hyperparameters:
# {'initial_units': 160, 'num_blocks': 4, 'block_0_units': 256, 'dropout_0': 0.5, 'lr': 0.00011811840774830564, 'block_1_units': 128, 'dropout_1': 0.30000000000000004, 'block_2_units': 64, 'dropout_2': 0.1, 'block_3_units': 64, 'dropout_3': 0.1}

# %%
# Rebuild models with best hyperparameters
def build_final_first_model(hp):
    model = keras.Sequential()
    model.add(layers.BatchNormalization(input_shape=(X_train.shape[1],)))

    # Build with best hyperparameters
    for i in range(hp.get('num_layers')):
        model.add(layers.Dense(
            units=hp.get(f'units_{i}'),
            activation='relu'
        ))
        model.add(layers.BatchNormalization())
        model.add(layers.Dropout(
            rate=hp.get(f'dropout_{i}')
        ))

    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(
        optimizer=keras.optimizers.Adam(
            learning_rate=hp.get('lr'),
            clipnorm=1.0
        ),
        loss='binary_crossentropy',
        metrics=['accuracy', keras.metrics.AUC(name='auc')]
    )
    return model

def build_final_second_model(hp):
    inputs = keras.Input(shape=(X_train.shape[1],))
    x = layers.Dense(
        hp.get('initial_units'),
        activation='relu'
    )(inputs)
    x = layers.BatchNormalization()(x)

    # Build with best hyperparameters
    for i in range(hp.get('num_blocks')):
        residual = x
        units = hp.get(f'block_{i}_units')

        x = layers.Dense(units, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(
            hp.get(f'dropout_{i}')
        )(x)
        x = layers.Dense(residual.shape[-1])(x)
        x = layers.add([x, residual])
        x = layers.Activation('relu')(x)

    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = keras.Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer=keras.optimizers.Adam(
            learning_rate=hp.get('lr'),
            clipnorm=1.0
        ),
        loss='binary_crossentropy',
        metrics=['accuracy', keras.metrics.AUC(name='auc')]
    )
    return model

# Build final models
final_first_model = build_final_first_model(best_first_hps)
final_second_model = build_final_second_model(best_second_hps)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Callbacks
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    restore_best_weights=True,
    monitor='val_auc',
    mode='max'
)

# Train models
print("Training first model:")
first_history = final_first_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)

print("Training second model:")
second_history = final_second_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Training first model:
# Epoch 1/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 16s 15ms/step - accuracy: 0.6273 - auc: 0.6737 - loss: 0.7521 - val_accuracy: 0.7102 - val_auc: 0.7805 - val_loss: 0.5599
# Epoch 2/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6884 - auc: 0.7493 - loss: 0.5957 - val_accuracy: 0.7161 - val_auc: 0.7890 - val_loss: 0.5513
# Epoch 3/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7054 - auc: 0.7739 - loss: 0.5659 - val_accuracy: 0.7184 - val_auc: 0.7925 - val_loss: 0.5462
# Epoch 4/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7171 - auc: 0.7846 - loss: 0.5551 - val_accuracy: 0.7204 - val_auc: 0.7940 - val_loss: 0.5440
# Epoch 5/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7174 - auc: 0.7878 - loss: 0.5497 - val_accuracy: 0.7208 - val_auc: 0.7938 - val_loss: 0.5448
# Epoch 6/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7165 - auc: 0.7883 - loss: 0.5491 - val_accuracy: 0.7210 - val_auc: 0.7952 - val_loss: 0.5435
# Epoch 7/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7193 - auc: 0.7934 - loss: 0.5440 - val_accuracy: 0.7221 - val_auc: 0.7961 - val_loss: 0.5420
# Epoch 8/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7202 - auc: 0.7926 - loss: 0.5448 - val_accuracy: 0.7210 - val_auc: 0.7959 - val_loss: 0.5432
# Epoch 9/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7224 - auc: 0.7943 - loss: 0.5433 - val_accuracy: 0.7211 - val_auc: 0.7966 - val_loss: 0.5420
# Epoch 10/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7221 - auc: 0.7974 - loss: 0.5393 - val_accuracy: 0.7220 - val_auc: 0.7970 - val_loss: 0.5423
# Epoch 11/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7249 - auc: 0.7979 - loss: 0.5390 - val_accuracy: 0.7239 - val_auc: 0.7978 - val_loss: 0.5414
# Epoch 12/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7261 - auc: 0.7991 - loss: 0.5374 - val_accuracy: 0.7263 - val_auc: 0.7981 - val_loss: 0.5406
# Epoch 13/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7253 - auc: 0.8008 - loss: 0.5349 - val_accuracy: 0.7229 - val_auc: 0.7980 - val_loss: 0.5411
# Epoch 14/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7281 - auc: 0.7995 - loss: 0.5366 - val_accuracy: 0.7244 - val_auc: 0.7992 - val_loss: 0.5408
# Epoch 15/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7251 - auc: 0.8025 - loss: 0.5330 - val_accuracy: 0.7242 - val_auc: 0.7994 - val_loss: 0.5397
# Epoch 16/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7292 - auc: 0.8040 - loss: 0.5304 - val_accuracy: 0.7244 - val_auc: 0.7980 - val_loss: 0.5434
# Epoch 17/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7288 - auc: 0.8044 - loss: 0.5312 - val_accuracy: 0.7238 - val_auc: 0.7988 - val_loss: 0.5420
# Epoch 18/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7300 - auc: 0.8053 - loss: 0.5299 - val_accuracy: 0.7239 - val_auc: 0.7986 - val_loss: 0.5423
# Epoch 19/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7271 - auc: 0.8050 - loss: 0.5306 - val_accuracy: 0.7224 - val_auc: 0.7988 - val_loss: 0.5412
# Epoch 20/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7333 - auc: 0.8077 - loss: 0.5263 - val_accuracy: 0.7239 - val_auc: 0.7995 - val_loss: 0.5408
# Epoch 21/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7322 - auc: 0.8095 - loss: 0.5241 - val_accuracy: 0.7231 - val_auc: 0.7993 - val_loss: 0.5411
# Epoch 22/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7334 - auc: 0.8096 - loss: 0.5241 - val_accuracy: 0.7246 - val_auc: 0.7986 - val_loss: 0.5429
# Epoch 23/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7352 - auc: 0.8099 - loss: 0.5246 - val_accuracy: 0.7244 - val_auc: 0.7988 - val_loss: 0.5433
# Epoch 24/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7322 - auc: 0.8093 - loss: 0.5248 - val_accuracy: 0.7238 - val_auc: 0.7985 - val_loss: 0.5435
# Epoch 25/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7320 - auc: 0.8115 - loss: 0.5217 - val_accuracy: 0.7245 - val_auc: 0.7984 - val_loss: 0.5452
# Training second model:
# Epoch 1/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - accuracy: 0.5734 - auc: 0.5944 - loss: 0.7701 - val_accuracy: 0.6863 - val_auc: 0.7546 - val_loss: 0.5815
# Epoch 2/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.6601 - auc: 0.7155 - loss: 0.6289 - val_accuracy: 0.6975 - val_auc: 0.7726 - val_loss: 0.5670
# Epoch 3/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6796 - auc: 0.7435 - loss: 0.5993 - val_accuracy: 0.7103 - val_auc: 0.7811 - val_loss: 0.5593
# Epoch 4/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6926 - auc: 0.7593 - loss: 0.5843 - val_accuracy: 0.7103 - val_auc: 0.7840 - val_loss: 0.5565
# Epoch 5/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6945 - auc: 0.7635 - loss: 0.5768 - val_accuracy: 0.7129 - val_auc: 0.7855 - val_loss: 0.5553
# Epoch 6/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7028 - auc: 0.7727 - loss: 0.5669 - val_accuracy: 0.7168 - val_auc: 0.7889 - val_loss: 0.5521
# Epoch 7/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7052 - auc: 0.7771 - loss: 0.5631 - val_accuracy: 0.7196 - val_auc: 0.7904 - val_loss: 0.5510
# Epoch 8/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7104 - auc: 0.7785 - loss: 0.5615 - val_accuracy: 0.7183 - val_auc: 0.7914 - val_loss: 0.5491
# Epoch 9/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7111 - auc: 0.7828 - loss: 0.5550 - val_accuracy: 0.7215 - val_auc: 0.7930 - val_loss: 0.5482
# Epoch 10/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7152 - auc: 0.7861 - loss: 0.5530 - val_accuracy: 0.7189 - val_auc: 0.7937 - val_loss: 0.5469
# Epoch 11/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7176 - auc: 0.7886 - loss: 0.5507 - val_accuracy: 0.7227 - val_auc: 0.7943 - val_loss: 0.5458
# Epoch 12/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7176 - auc: 0.7904 - loss: 0.5470 - val_accuracy: 0.7230 - val_auc: 0.7956 - val_loss: 0.5467
# Epoch 13/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7191 - auc: 0.7915 - loss: 0.5464 - val_accuracy: 0.7231 - val_auc: 0.7959 - val_loss: 0.5456
# Epoch 14/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7212 - auc: 0.7944 - loss: 0.5430 - val_accuracy: 0.7238 - val_auc: 0.7972 - val_loss: 0.5437
# Epoch 15/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7210 - auc: 0.7959 - loss: 0.5414 - val_accuracy: 0.7230 - val_auc: 0.7974 - val_loss: 0.5442
# Epoch 16/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7227 - auc: 0.7947 - loss: 0.5424 - val_accuracy: 0.7227 - val_auc: 0.7979 - val_loss: 0.5451
# Epoch 17/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7239 - auc: 0.7976 - loss: 0.5391 - val_accuracy: 0.7193 - val_auc: 0.7979 - val_loss: 0.5440
# Epoch 18/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7222 - auc: 0.7984 - loss: 0.5383 - val_accuracy: 0.7209 - val_auc: 0.7976 - val_loss: 0.5442
# Epoch 19/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7273 - auc: 0.8014 - loss: 0.5348 - val_accuracy: 0.7234 - val_auc: 0.7991 - val_loss: 0.5421
# Epoch 20/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7267 - auc: 0.8029 - loss: 0.5324 - val_accuracy: 0.7235 - val_auc: 0.7986 - val_loss: 0.5432
# Epoch 21/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7296 - auc: 0.8052 - loss: 0.5295 - val_accuracy: 0.7227 - val_auc: 0.7992 - val_loss: 0.5423
# Epoch 22/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7241 - auc: 0.8037 - loss: 0.5311 - val_accuracy: 0.7242 - val_auc: 0.7995 - val_loss: 0.5424
# Epoch 23/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7297 - auc: 0.8050 - loss: 0.5310 - val_accuracy: 0.7249 - val_auc: 0.8002 - val_loss: 0.5407
# Epoch 24/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7335 - auc: 0.8093 - loss: 0.5246 - val_accuracy: 0.7253 - val_auc: 0.7994 - val_loss: 0.5434
# Epoch 25/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7294 - auc: 0.8074 - loss: 0.5280 - val_accuracy: 0.7231 - val_auc: 0.7991 - val_loss: 0.5421
# Epoch 26/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7347 - auc: 0.8104 - loss: 0.5243 - val_accuracy: 0.7243 - val_auc: 0.7990 - val_loss: 0.5436
# Epoch 27/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7345 - auc: 0.8117 - loss: 0.5221 - val_accuracy: 0.7221 - val_auc: 0.7994 - val_loss: 0.5442
# Epoch 28/100
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7358 - auc: 0.8124 - loss: 0.5205 - val_accuracy: 0.7224 - val_auc: 0.7996 - val_loss: 0.5447

# %%
# Save final models
final_first_model.save('/content/drive/MyDrive/ACTL3143_project/models/final_first_dl_model.keras')
final_second_model.save('/content/drive/MyDrive/ACTL3143_project/models/final_second_dl_model.keras')
